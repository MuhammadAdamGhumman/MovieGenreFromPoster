# %%
# conventional way to import pandas
import pandas as pd

# %%
# how to create data Frame
mydf = pd.DataFrame({'Roll no':[1,2,3,4,5],'Name':['Ali','Ahmed','Qasim', 'Ayesha','Aleena'],'GPA':['good','good','very good','bad','Excellent']})

# %%
mydf
# Out:
#    Roll no    Name        GPA
# 0        1     Ali       good
# 1        2   Ahmed       good
# 2        3   Qasim  very good
# 3        4  Ayesha        bad
# 4        5  Aleena  Excellent

# %%
mydf.shape
# Out:
# (5, 3)

# %%
mydf.sort_values('GPA')
# Out:
#    Roll no    Name        GPA
# 4        5  Aleena  Excellent
# 3        4  Ayesha        bad
# 0        1     Ali       good
# 1        2   Ahmed       good
# 2        3   Qasim  very good

# %%
# create a new data frame "yourname_df" like "asad_df" and fill values
# with fiend names and ages (3 friend details) [use dictionary]
adam_df = pd.DataFrame({'Roll no':[1,2,3,4,5],'Name':['Adam','Aiyan','Ali', 'Arslan','Saad'],'GPA':['very bad','very bad','lmao','very bad','Excellent']})
adam_df
# Out:
#    Roll no    Name        GPA
# 0        1    Adam   very bad
# 1        2   Aiyan   very bad
# 2        3     Ali       lmao
# 3        4  Arslan   very bad
# 4        5    Saad  Excellent

# %%
# check shape of your data frame
adam_df.shape
# Out:
# (5, 3)

# %%
# create a DataFrame from a dictionary (keys become column names, values become data)
pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']})
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
# optionally specify the order of columns
df = pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']}, columns=['id', 'color'])
df
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
# optionally specify the order of columns and define the index
df = pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']}, columns=['id', 'color'], index=['a', 'b', 'c'])
df
# Out:
#     id color
# a  100   red
# b  101  blue
# c  102   red

# %%
# create a new data frame "yourname_df" like "asad_df" and fill values
# with fiend names and ages (3 friend details) [use dictionary] and 
# index should be age

# %%
# create a DataFrame from a list of lists (each inner list becomes a row)
dfx = pd.DataFrame([[100, 'red'], [101, 'blue'], [102, 'red']], columns=['color','id'])

# %%
dfx
# Out:
#    color    id
# 0    100   red
# 1    101  blue
# 2    102   red

# %%
# create a new data frame "yourname_df" like "asad_df" and fill values
# with fiend names and ages (3 friend details) [use list]

adam_df = pd.DataFrame([['Adam', 'BSCS17051'], ['Aiyan', 'BSCS17025'], ['Saad', 'BSCS17039']], columns=['name','id'])
adam_df
# Out:
#     name         id
# 0   Adam  BSCS17051
# 1  Aiyan  BSCS17025
# 2   Saad  BSCS17039

# %%
# create a NumPy array (with shape 4 by 2) and fill it with random numbers between 0 and 1
import numpy as np
arr = np.random.rand(4, 2)
arr
# Out:
# array([[0.67376931, 0.38715514],
#        [0.36566145, 0.228934  ],
#        [0.21873429, 0.04113349],
#        [0.86948358, 0.30915713]])

# %%
a = pd.DataFrame(arr)
a
# Out:
#           0         1
# 0  0.673769  0.387155
# 1  0.365661  0.228934
# 2  0.218734  0.041133
# 3  0.869484  0.309157

# %%
a[0]
# Out:
# 0    0.673769
# 1    0.365661
# 2    0.218734
# 3    0.869484
# Name: 0, dtype: float64

# %%
# create a DataFrame from the NumPy array
b = pd.DataFrame(arr, columns=['one', 'two'])
b
# Out:
#         one       two
# 0  0.673769  0.387155
# 1  0.365661  0.228934
# 2  0.218734  0.041133
# 3  0.869484  0.309157

# %%
#b['two']
b.two
# Out:
# 0    0.387155
# 1    0.228934
# 2    0.041133
# 3    0.309157
# Name: two, dtype: float64

# %%
# create a dataframe with your name by using NumPy array (with shape 10 
# by 3) and fill it with random numbers between 5 and 10. 
# Column names should should be first, second, third
arr = np.random.rand(10, 3)+5
adam_df = pd.DataFrame(arr, columns=['one', 'two', 'three'])
adam_df
# Out:
#         one       two     three
# 0  5.469355  5.035273  5.059936
# 1  5.932812  5.021335  5.498880
# 2  5.395334  5.225530  5.603349
# 3  5.504990  5.258561  5.184185
# 4  5.455558  5.962576  5.905862
# 5  5.072280  5.906342  5.220201
# 6  5.382848  5.660833  5.710746
# 7  5.272740  5.253972  5.263896
# 8  5.237097  5.223106  5.467943
# 9  5.433450  5.533345  5.957222

# %%
# create a DataFrame of student IDs (100 through 109) and test scores (random integers between 60 and 100)
c = pd.DataFrame({'student':np.arange(100, 110, 1), 'test':np.random.randint(60, 101, 10)})

# %%
c.head()
# Out:
#    student  test
# 0      100    78
# 1      101    70
# 2      102    89
# 3      103    80
# 4      104    65

# %%
# 'set_index' can be chained with the DataFrame constructor to select an index
p = pd.DataFrame({'student':np.arange(100, 110, 1), 'test':np.random.randint(60, 101, 10)}).set_index('student')
p.head()
# Out:
#          test
# student
# 100        72
# 101        77
# 102        68
# 103        70
# 104        99

# %%
p = pd.DataFrame({'student':np.arange(100, 110, 1), 'test':np.random.randint(60, 101, 10)})
p.head()
# Out:
#    student  test
# 0      100    94
# 1      101    75
# 2      102    84
# 3      103    86
# 4      104    60

# %%
p.set_index ('student')
#print(p.head())
# Out:
#          test
# student
# 100        94
# 101        75
# 102        84
# 103        86
# 104        60
# 105        99
# 106        65
# 107        74
# 108        83
# 109        84

# %%
# read a dataset of Chipotle orders directly from a URL and store the results in a DataFrame
#orders = pd.read_table('http://bit.ly/chiporders')

# read a dataset of Chipotle orders directly from a file stored on disk and store the results in a DataFrame
orders = pd.read_table('data/chipotle.tsv')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
pd.read_table('data/movieusers.tsv').head() # seprator '|' is not defined
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
pd.read_table('data/movieusers.tsv',sep='|').head() # first row was selected as header
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
pd.read_table('data/movieusers.tsv',sep='|', header=None).head() # default numbers are assigned to each column
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
# defining user defined Column names
ucol = ['id','age','gender','occupation','code']
user = pd.read_table('data/movieusers.tsv',sep='|', header=None,names=ucol)

# %%
user.tail()
# Please read skiprow and skipfooter parameter of read_table
# Out:
#       id  age gender     occupation   code
# 938  939   26      F        student  33319
# 939  940   32      M  administrator  02215
# 940  941   20      M        student  97229
# 941  942   48      F      librarian  78209
# 942  943   22      M        student  77841

# %%
pd.read_table('data/ufo.csv').head()
# Out:
#   City,Colors Reported,Shape Reported,State,Time
# 0             Ithaca,,TRIANGLE,NY,6/1/1930 22:00
# 1           Belton,RED,SPHERE,SC,6/30/1939 20:00
# 2          Willingboro,,OTHER,NJ,6/30/1930 20:00
# 3               Holyoke,,OVAL,CO,2/15/1931 14:00
# 4                Abilene,,DISK,KS,6/1/1931 13:00

# %%
ufo = pd.read_table('data/ufo.csv',sep=',')
ufo.head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 4      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
ufo2 = pd.read_csv('data/ufo.csv')
ufo2.head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 4      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
# if we want to read only selected columns
ufo2 = pd.read_csv('data/ufo.csv', usecols=['City','State'])
#### OR ####
#ufo2 = pd.read_csv('data/ufo.csv', usecols=[0,3])
ufo2.head()
# Out:
#           City State
# 0       Ithaca    NY
# 1       Belton    SC
# 2  Willingboro    NJ
# 3      Holyoke    CO
# 4      Abilene    KS

# %%
# to read only top rows
ufo = pd.read_csv('data/ufo.csv', nrows=4)
ufo.head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
#import pandas as pd
ufo1 = pd.read_csv('data/ufo.csv')
ufo1.head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 4      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
type(ufo1['City'])
# Out:
# pandas.core.series.Series

# %%
# to select a particular series from DF. its case sensitive
ufo1["City"] # it returns first thirty and last thirty
# Out:
# 0             Ithaca
# 1             Belton
# 2        Willingboro
# 3            Holyoke
# 4            Abilene
#             ...
# 18240     Grant Park
# 18241    Spirit Lake
# 18242    Eagle River
# 18243    Eagle River
# 18244           Ybor
# Name: City, Length: 18245, dtype: object

# %%
ufo1.City # Dot notation can also be used for series
# Out:
# 0             Ithaca
# 1             Belton
# 2        Willingboro
# 3            Holyoke
# 4            Abilene
#             ...
# 18240     Grant Park
# 18241    Spirit Lake
# 18242    Eagle River
# 18243    Eagle River
# 18244           Ybor
# Name: City, Length: 18245, dtype: object

# %%
ufo1.head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 4      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %% [markdown]
# Important Note: When ever a series is added to DF, it automatically becomes attribute of DF

# %%
# how to select series of Colors Reported?
# if there is space in the name then dot notation will not help and col name should not match with built in fuction like shape, head etc
ufo1['Colors Reported']
# Out:
# 0        NaN
# 1        RED
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18240    NaN
# 18241    NaN
# 18242    NaN
# 18243    RED
# 18244    NaN
# Name: Colors Reported, Length: 18245, dtype: object

# %%
# to concatenate two series
#'abd'+'dee'
ufo1.City + ' , ' + ufo1.State
# Out:
# 0             Ithaca , NY
# 1             Belton , SC
# 2        Willingboro , NJ
# 3            Holyoke , CO
# 4            Abilene , KS
#                ...
# 18240     Grant Park , IL
# 18241    Spirit Lake , IA
# 18242    Eagle River , WI
# 18243    Eagle River , WI
# 18244           Ybor , FL
# Length: 18245, dtype: object

# %%
# to create a new series in DF don't use dot notation, For assignment it is necessary that we should use barcket notation
ufo1['Location'] = ufo1.City + ' , ' + ufo1.State
ufo1.head()
# Out:
#           City Colors Reported Shape Reported State             Time  \
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 4      Abilene             NaN           DISK    KS   6/1/1931 13:00
#
#            Location
# 0       Ithaca , NY
# 1       Belton , SC
# 2  Willingboro , NJ
# 3      Holyoke , CO
# 4      Abilene , KS

# %%
#import pandas as pd
movies = pd.read_csv('data/imdb_1000.csv')
movies.head() # example of method
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes # example of attribute
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# shows statistics of numeric colums
movies.describe() # example of method
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.describe(include=['object']) # describes only Object type attributes
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.shape # example of attribute
# Out:
# (979, 6)

# %% [markdown]
# Rename Columns?

# %%
ufo1.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo1.head()
# Out:
#           City Colors Reported Shape Reported State             Time  \
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 3      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 4      Abilene             NaN           DISK    KS   6/1/1931 13:00
#
#            Location
# 0       Ithaca , NY
# 1       Belton , SC
# 2  Willingboro , NJ
# 3      Holyoke , CO
# 4      Abilene , KS

# %%
ufo1.rename(columns={'Colors Reported': 'Colors_Reported', 'Shape Reported':'Shape_Reported'}) 
ufo1.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
# inplace = True to show the impact in existing DF
ufo1.rename(columns={'Colors Reported': 'Colors_Reported', 'Shape Reported':'Shape_Reported'},inplace=True) 
ufo1.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
# Another Method of renaming the columns
mycol = ['city','color reported', 'shape reported','state','time', 'location']
ufo1.columns = mycol

# %%
ufo1.columns
# Out:
# Index(['city', 'color reported', 'shape reported', 'state', 'time',
#        'location'],
#       dtype='object')

# %%
# Renaming the columns names while reading
#import pandas as pd
mycol = ['city','color reported', 'shape reported','state','time', 'location']
ufo = pd.read_csv('data/ufo.csv',names=mycol)
ufo.head()
# Out:
#           city   color reported  shape reported  state             time  \
# 0         City  Colors Reported  Shape Reported  State             Time
# 1       Ithaca              NaN        TRIANGLE     NY   6/1/1930 22:00
# 2       Belton              RED          SPHERE     SC  6/30/1939 20:00
# 3  Willingboro              NaN           OTHER     NJ  6/30/1930 20:00
# 4      Holyoke              NaN            OVAL     CO  2/15/1931 14:00
#
#    location
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Assume you have thousands of col with spaces in between
ufo.columns = ufo.columns.str.replace(' ','_')
ufo.columns
# Out:
# Index(['city', 'color_reported', 'shape_reported', 'state', 'time',
#        'location'],
#       dtype='object')

# %% [markdown]
# Remove Columns from DF

# %%
# use axis = 1 to drop column
ufodrp = ufo.drop('shape_reported', axis=1) # this will not effect the current object i.e., ufo. You can confirm this by using ufo.columns command

# %%
ufo.head()
# Out:
#           city   color_reported  shape_reported  state             time  \
# 0         City  Colors Reported  Shape Reported  State             Time
# 1       Ithaca              NaN        TRIANGLE     NY   6/1/1930 22:00
# 2       Belton              RED          SPHERE     SC  6/30/1939 20:00
# 3  Willingboro              NaN           OTHER     NJ  6/30/1930 20:00
# 4      Holyoke              NaN            OVAL     CO  2/15/1931 14:00
#
#    location
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
ufo.drop('shape_reported', axis=1, inplace=True)

# %%
ufo.columns
# Out:
# Index(['city', 'color_reported', 'state', 'time', 'location'], dtype='object')

# %%
ufo.head()
# Out:
#           city   color_reported  state             time  location
# 0         City  Colors Reported  State             Time       NaN
# 1       Ithaca              NaN     NY   6/1/1930 22:00       NaN
# 2       Belton              RED     SC  6/30/1939 20:00       NaN
# 3  Willingboro              NaN     NJ  6/30/1930 20:00       NaN
# 4      Holyoke              NaN     CO  2/15/1931 14:00       NaN

# %%
# to drop multiple columns, use list of strings
ufo.drop(['city', 'time'], axis=1, inplace=True)
ufo.head()
# Out:
#     color_reported  state  location
# 0  Colors Reported  State       NaN
# 1              NaN     NY       NaN
# 2              RED     SC       NaN
# 3              NaN     NJ       NaN
# 4              NaN     CO       NaN

# %%
# use axis = 0 to drop rows
ufo.drop([0,1],axis=0,inplace=True)

# %%
ufo.head()
# Out:
#   color_reported state  location
# 2            RED    SC       NaN
# 3            NaN    NJ       NaN
# 4            NaN    CO       NaN
# 5            NaN    KS       NaN
# 6            NaN    NY       NaN

# %% [markdown]
# how to sort DF or Series

# %%
#import pandas as pd
movies = pd.read_csv('data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies['title']
#movies.title.sort_values()
#movies['duration'].sort_values(ascending = False) # it returns panda series and default is assending order
#movies['title'].sort_values(ascending=False)
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
# sorting entire DF on a particular topic
movies.sort_values('title',ascending=True).head()
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...

# %%
# sorting by mulitple columns
#movies.head()
movies.sort_values(['star_rating','duration']).head()
# Out:
#      star_rating                title content_rating      genre  duration  \
# 938          7.4  Alice in Wonderland              G  Animation        75
# 948          7.4           Frances Ha              R     Comedy        86
# 966          7.4   The Simpsons Movie          PG-13  Animation        87
# 947          7.4           Eraserhead        UNRATED      Drama        89
# 971          7.4   Death at a Funeral              R     Comedy        90
#
#                                            actors_list
# 938  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 966  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 971  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...

# %% [markdown]
# Filter Rows on DF

# %%
# conventional appraoch
bl = []
for d in movies.duration:
    if d>=200:
        bl.append(True)
    else:
        bl.append(False)
len(bl)
# Out:
# 979

# %%
bl[0:5]
# Out:
# [False, False, True, False, False]

# %%
# converting into series
pbl = pd.Series(bl)
pbl.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
movies[pbl]
#movies.head()
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
# simple version
pbl1 = movies.duration >= 200
#pbl1.head()
movies[pbl1]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
#movies[movies.duration>=200]
#movies[movies.duration>=200].duration
#movies[movies.duration>=200]['duration']
#movies
#movies.loc[1,'star_rating']
#movies.loc[movies.duration>=200, 'duration']# recommended approach
#movies.loc[movies.duration>=200, ['duration','title']]# recommended approach
movies.loc[0:5:2, ['duration','title']]
# Out:
#    duration                     title
# 0       142  The Shawshank Redemption
# 2       200    The Godfather: Part II
# 4       154              Pulp Fiction

# %% [markdown]
# ## Apply Multiple filters

# %%
#movies[movies.duration>=200 & movies.genre=='Crime'] # this will not work
movies[(movies.duration>=200) & (movies.genre=='Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
# if we use multiple condition on single attribute 
movies[(movies.genre=='Drama') | (movies.genre=='Crime') | (movies.genre=='Action')]
# or we can use isin method
#movies[movies.genre.isin(['Drama','Crime','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
# how to iterate DF and series
movies = pd.read_csv('data/imdb_1000.csv', nrows=5)
movies.head()
# for series
#for d in movies.duration:
#    print (d)
# for DF
for index, r in movies.iterrows():
    print (index, r.title, r.genre)
# Out:
# 0 The Shawshank Redemption Crime
# 1 The Godfather Crime
# 2 The Godfather: Part II Crime
# 3 The Dark Knight Action
# 4 Pulp Fiction Crime

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# How to drop every non-numeric column from DF

# %%
drinks = pd.read_csv('data/drinks.csv')
drinks.dtypes
#import numpy as np
#drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#discussion about axis
#drinks.drop('continent',axis=1) # to drop a col
#drinks.drop(1,axis=0).head() # to drop a row
#drinks.head()
#drinks.mean(axis=0) # returns col wise mean
#drinks.mean(axis=1) # returns row wise mean
drinks.mean(axis='index') # returns col wise mean.  0 --> index
#drinks.mean(axis='columns') # returns row wise mean.  1 --> columns
#drinks.index # returns rows idshttp://localhost:8888/notebooks/Python%20pandas.ipynb#
#drinks.columns # returns column names
#drinks.loc[23,'country'] # getting content of a cell by providing rows and columns
#drinks.set_index('country', inplace=True) # coverting country as row index
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks
#drinks.loc['Pakistan','beer_servings']
#drinks.loc[drinks.country == 'pakistan','beer_servings']
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.loc['Albania','beer_servings']
#drinks.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Albania'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-8a8dcba9a82e> in <module>
# ----> 1 drinks.loc['Albania','beer_servings']
#       2 #drinks.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
#drinks.index
#drinks.columns
#drinks.loc['Brazil','beer_servings']
drinks.index.name = None # removing the word "country" from rows
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# how you can see country is at appropriate location
drinks.index.name = 'Country'
drinks.reset_index(inplace = True)
drinks.head()
# Out:
#    Country      country  beer_servings  spirit_servings  wine_servings  \
# 0        0  Afghanistan              0                0              0
# 1        1      Albania             89              132             54
# 2        2      Algeria             25                0             14
# 3        3      Andorra            245              138            312
# 4        4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks = pd.read_csv('data/drinks.csv')
drinks.set_index('country', inplace=True)
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
people = pd.Series([3000000, 85000], index=['Albania', 'Andorra'], name='population')
people
# Out:
# Albania    3000000
# Andorra      85000
# Name: population, dtype: int64

# %%
drinks.beer_servings
# Out:
# country
# Afghanistan      0
# Albania         89
# Algeria         25
# Andorra        245
# Angola         217
#               ...
# Venezuela      333
# Vietnam        111
# Yemen            6
# Zambia          32
# Zimbabwe        64
# Name: beer_servings, Length: 193, dtype: int64

# %%
(drinks.beer_servings * people).head()
# Out:
# Afghanistan            NaN
# Albania        267000000.0
# Algeria                NaN
# Andorra         20825000.0
# Angola                 NaN
# dtype: float64

# %%
#drinks.head()
# concatenate a series to DF
pd.concat([drinks,people], axis=1)
# Out:
# C:\Users\Adam\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# ...

# %% [markdown]
# String Methods in PD

# %%
#drinks
#drinks.reset_index(inplace = True)
#drinks.country.str.upper()
#drinks.country
#drinks.country.str.contains('ist')
#drinks[drinks.country.str.contains('ist')]
# for detail you can see Pandas API Reference https://pandas.pydata.org/pandas-docs/stable/api.html --> String Handeling
drinks.country.str.replace('ist', 'IST').str.replace('Af', 'AF') # concating multiple str operations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-bd290a701506> in <module>
#       6 #drinks[drinks.country.str.contains('ist')]
#       7 # for detail you can see Pandas API Reference https://pandas.pydata.org/pandas-docs/stable/api.html --> String Handeling
# ----> 8 drinks.country.str.replace('ist', 'IST').str.replace('Af', 'AF') # concating multiple str operations
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'country'

# %% [markdown]
# Change Data types of series

# %%
drinks.dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings'] = drinks.beer_servings.astype(float)
drinks.dtypes
# Out:
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# how to change the data type while reading CSV
drinks = pd.read_csv('data/drinks.csv',dtype={'beer_servings':float})
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# if we want to find 'ist' and want to create a new fueture of 0 and 1 
#drinks.country.str.contains('ist') # return boolean type array
drinks.country.str.contains('ist').astype(int)                  # convters into 1 and 0
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 188    0
# 189    0
# 190    0
# 191    0
# 192    0
# Name: country, Length: 193, dtype: int32

# %% [markdown]
# Group By

# %%
#drinks.describe()
#drinks[drinks.continent=='Asia'].beer_servings.mean()
#drinks[drinks.continent=='Europe'].beer_servings.mean()
#drinks[drinks.continent=='Africa'].beer_servings.mean()
#drinks.groupby('continent').beer_servings.mean()
#drinks.groupby('continent').beer_servings.max()
#drinks.groupby('continent').beer_servings.min()
drinks.groupby('continent').beer_servings.agg(['count','max','min','mean'])
#drinks.groupby('continent').mean() # if we don't specify col then it will create mean of all cols
#drinks.groupby('continent').max()
# Out:
#                count    max   min        mean
# continent
# Africa            53  376.0   0.0   61.471698
# Asia              44  247.0   0.0   37.045455
# Europe            45  361.0   0.0  193.777778
# North America     23  285.0   1.0  145.434783
# Oceania           16  306.0   0.0   89.687500
# South America     12  333.0  93.0  175.083333

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# %matplotlib inline

# %%
# to view table results in graphical form
drinks.groupby('continent').mean().plot(kind='bar')

# %% [markdown]
# Explore panda Series

# %%
#movies = pd.read_csv('data/imdb_1000.csv')
#movies
#movies.dtypes
#movies.describe()
#movies.genre
#movies.genre.describe()
movies.genre.value_counts()
#movies.genre.value_counts(normalize=True) # return %ages
#type(movies.genre.value_counts(normalize=True))
#movies.genre.value_counts(normalize=True).head()
#movies.genre.unique()
#movies.genre.nunique()
# Out:
# Crime     4
# Action    1
# Name: genre, dtype: int64

# %%
#movies
#movies.content_rating.describe()
#movies.content_rating.value_counts()

#print(movies.content_rating.unique())
#pd.crosstab(movies.genre,movies.content_rating)
#movies.duration.describe()
#movies.duration.mean()
movies.duration.value_counts()
# Out:
# 175    1
# 142    1
# 152    1
# 154    1
# 200    1
# Name: duration, dtype: int64

# %%
# %matplotlib inline

# %%
movies.content_rating.value_counts().plot(kind = 'bar')
#movies.duration.plot(kind='hist')
#movies.duration.plot(kind='bar')

# %%
#movies.duration.plot()
#movies.duration.plot(kind='hist')
#movies.duration.plot(kind='bar')
movies.duration.value_counts().plot(kind='bar')

# %% [markdown]
# Handeling missing values

# %%
import pandas as pd
ufo = pd.read_csv('data/ufo.csv')
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18240   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18241  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18242  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18243  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18244         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15362
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.notnull().sum()
# Out:
# City               18220
# Colors Reported     2883
# Shape Reported     15601
# State              18245
# Time               18245
# dtype: int64

# %%
ufo.isnull().sum() # returns no. of sums of missing values
# Out:
# City                  25
# Colors Reported    15362
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
# how above statement works
pd.Series([True,False,True]).sum() # it converts Trues to 1 and False to 0
# Out:
# 2

# %%
#ufo[ufo.City.isnull()]
ufo[ufo.City.notnull()]
# Out:
#               City Colors Reported Shape Reported State              Time
# 0           Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Belton             RED         SPHERE    SC   6/30/1939 20:00
# 2      Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 3          Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 4          Abilene             NaN           DISK    KS    6/1/1931 13:00
# ...            ...             ...            ...   ...               ...
# 18240   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18241  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18242  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18243  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18244         Ybor             NaN           OVAL    FL  12/31/2000 23:59
#
# [18220 rows x 5 columns]

# %%
# how to deal with missing value, there are many possible solution and some of them are given below
ufo.shape
# Out:
# (18245, 5)

# %%
ufo.dropna(how='any').shape # drops all rows that contains ANY of five columns have missing value
# Out:
# (2487, 5)

# %%
ufo.dropna(how='all').shape # drops all rows that contains ALL of five columns have missing value
# Out:
# (18245, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'], how='any').shape # drops all rows that contains ANY of two columns have missing values
# Out:
# (15580, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'], how='all').shape # drops all rows that contains All of two columns have missing values
# Out:
# (18241, 5)

# %%
#ufo['Shape Reported'].value_counts()
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2124
# TRIANGLE     1889
# OTHER        1403
# CIRCLE       1365
# SPHERE       1055
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# PYRAMID         1
# HEXAGON         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %%
#ufo['Shape Reported'].fillna(value='VARIOUS') # replace NaN with Various,
ufo['Shape Reported'].fillna(value='VARIOUS', inplace=True, method=None) # replace NaN with Various,

# %%
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2124
# TRIANGLE     1889
# OTHER        1403
# CIRCLE       1365
# SPHERE       1055
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# FLARE           1
# DOME            1
# PYRAMID         1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo.head(10)
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1                Belton             RED         SPHERE    SC   6/30/1939 20:00
# 2           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 3               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 4               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 5  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 6           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 7           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 8                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 9               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00

# %%
ufo.loc[0,:] # zeroth row and all columns
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
ufo.loc[[0,1,2],:] # return 0,1 and 2nd row with all cols
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
#ufo.loc[0:10:2,:] 
# or
ufo.loc[0:2] # its not recommended
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 2  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
# for cols
#ufo.loc[:,'City']
#ufo.loc[:,['City','State']]
ufo.loc[1:5,'City':'State'] # all col between City and State
# Out:
#                    City Colors Reported Shape Reported State
# 1                Belton             RED         SPHERE    SC
# 2           Willingboro             NaN          OTHER    NJ
# 3               Holyoke             NaN           OVAL    CO
# 4               Abilene             NaN           DISK    KS
# 5  New York Worlds Fair             NaN          LIGHT    NY

# %%
ufo[ufo.City=='Alma']
# Out:
#        City Colors Reported Shape Reported State              Time
# 8      Alma             NaN           DISK    MI    7/15/1936 0:00
# 4300   Alma             NaN        VARIOUS    KS     6/1/1980 0:00
# 17742  Alma             NaN           OVAL    WI   10/21/2000 9:30
# 17778  Alma             NaN          LIGHT    NM  10/25/2000 21:05

# %%
ufo.loc[ufo.City=='Alma',:] # label based indexing
# Out:
#        City Colors Reported Shape Reported State              Time
# 8      Alma             NaN           DISK    MI    7/15/1936 0:00
# 4300   Alma             NaN        VARIOUS    KS     6/1/1980 0:00
# 17742  Alma             NaN           OVAL    WI   10/21/2000 9:30
# 17778  Alma             NaN          LIGHT    NM  10/25/2000 21:05

# %%
# for integer ranges
#ufo.iloc[:,[0,3]]
ufo.iloc[:,0:3] # last number is not included
#ufo.iloc[0:3,:] # 3 is exclued
# Out:
#               City Colors Reported Shape Reported
# 0           Ithaca             NaN       TRIANGLE
# 1           Belton             RED         SPHERE
# 2      Willingboro             NaN          OTHER
# 3          Holyoke             NaN           OVAL
# 4          Abilene             NaN           DISK
# ...            ...             ...            ...
# 18240   Grant Park             NaN       TRIANGLE
# 18241  Spirit Lake             NaN           DISK
# 18242  Eagle River             NaN        VARIOUS
# 18243  Eagle River             RED          LIGHT
# 18244         Ybor             NaN           OVAL
#
# [18245 rows x 3 columns]

# %% [markdown]
# How to DF smaller and Faster

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18245 entries, 0 to 18244
# Data columns (total 5 columns):
# City               18220 non-null object
# Colors Reported    2883 non-null object
# Shape Reported     18245 non-null object
# State              18245 non-null object
# Time               18245 non-null object
# dtypes: object(5)
# memory usage: 712.8+ KB

# %%
ufo.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18245 entries, 0 to 18244
# Data columns (total 5 columns):
# City               18220 non-null object
# Colors Reported    2883 non-null object
# Shape Reported     18245 non-null object
# State              18245 non-null object
# Time               18245 non-null object
# dtypes: object(5)
# memory usage: 5.4 MB

# %%
ufo.memory_usage() # memory useage in bytes
# Out:
# Index                 128
# City               145960
# Colors Reported    145960
# Shape Reported     145960
# State              145960
# Time               145960
# dtype: int64

# %%
ufo.memory_usage(deep=True) # return actual memory
# Out:
# Index                  128
# City               1205873
# Colors Reported     671469
# Shape Reported     1364511
# State              1076455
# Time               1307451
# dtype: int64

# %%
ufo.memory_usage(deep=True).sum()
# Out:
# 5625887

# %%
#len(sorted(ufo.State.unique()))
len(ufo.City.unique())
#len(ufo.State.unique())
# Out:
# 6477

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
# to assign one id against each state we can use "Category" Data type
ufo['State'] = ufo['State'].astype('category') # now by doing this internally integer will be stored instead of string

# %%
ufo.dtypes
# Out:
# City                 object
# Colors Reported      object
# Shape Reported       object
# State              category
# Time                 object
# dtype: object

# %%
ufo.State
# Out:
# 0        NY
# 1        SC
# 2        NJ
# 3        CO
# 4        KS
#          ..
# 18240    IL
# 18241    IA
# 18242    WI
# 18243    WI
# 18244    FL
# Name: State, Length: 18245, dtype: category
# Categories (52, object): [AK, AL, AR, AZ, ..., WA, WI, WV, WY]

# %%
ufo.State.cat.codes.head()
# Out:
# 0    35
# 1    41
# 2    32
# 3     5
# 4    17
# dtype: int8

# %%
ufo.memory_usage(deep=True)
# Note: if you do this for country this technique will not help in reducing memory size but it will 
# speed up computation
# Out:
# Index                  128
# City               1205873
# Colors Reported     671469
# Shape Reported     1364511
# State                23873
# Time               1307451
# dtype: int64

# %%
mydf = pd.DataFrame({'Roll no':[1,2,3,4,5],'Name':['Ali','Ahmed','Qasim', 'Ayesha','Aleena'],'GPA':['good','good','very good','good','Excellent']})
mydf.sort_values('GPA')
# Out:
#    Roll no    Name        GPA
# 4        5  Aleena  Excellent
# 0        1     Ali       good
# 1        2   Ahmed       good
# 3        4  Ayesha       good
# 2        3   Qasim  very good

# %%
mydf['GPA'] = mydf.GPA.astype('category', categories=['good', 'very good', 'Excellent'], ordered=True)
mydf.GPA
mydf.sort_values('GPA')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-d9f5bae4876c> in <module>
# ----> 1 mydf['GPA'] = mydf.GPA.astype('category', categories=['good', 'very good', 'Excellent'], ordered=True)
#       2 mydf.GPA
#       3 mydf.sort_values('GPA')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
# ...

# %%
mydf.loc[mydf.GPA > 'good',:] # we can condition on 'good' now becuase of above statement
# Out:
#    Roll no   Name        GPA
# 2        3  Qasim  very good

# %% [markdown]
# Kaggle Submission

# %%
train = pd.read_csv('data/titanic_train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# for selected no. of features
myfeatures = ['Pclass','Parch'] 
X = train.loc[:,myfeatures] # preparing traning Data and X will be of 'pandas.core.frame.DataFrame'
X.shape
# Out:
# (891, 2)

# %%
 y = train.Survived # extracting target labels of type pandas.core.series.Series
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# Note: There is no need to convert these pandas objects to NumPy arrays. scikit-learn will understand these objects as long as they are entirely numeric and the proper shapes.
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X, y)
# Out:
# C:\Users\Adam\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
test = pd.read_csv('data/titanic_test.csv')
Xtest = test.loc[:,myfeatures]
Xtest.shape
# Out:
# (418, 2)

# %%
predclass = logreg.predict(Xtest)

# %%
# for kaggle submission we need to things, 1) ID and 2) predicted results
pd.DataFrame({'Passangerid':test.PassengerId,'Survived':predclass})
# Out:
#      Passangerid  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# because dictionary doesn't maintaing ordering so use set index as Passangerid
pd.DataFrame({'Passangerid':test.PassengerId,'Survived':predclass}).set_index('Passangerid')
# Out:
#              Survived
# Passangerid
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 0
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                0
#
# [418 rows x 1 columns]

# %%
# to create csv file, use to_csv
pd.DataFrame({'Passangerid':test.PassengerId,'Survived':predclass}).set_index('Passangerid').to_csv('mysub.csv')

# %%
# to store DF on disk we use pickle
train.to_pickle('train.pkl')

# %%
# to read pickle file
pd.read_pickle('train.pkl')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# for random selection
#ufo.sample(n=3)  # for three random samples
#ufo.sample(n=3, random_state=2) # for reproducable three random samples
trn = ufo.sample(frac=0.75, random_state=2)  # for random selection of 75% data
tst = ufo.loc[~ufo.index.isin(trn.index),:] # for remaining 25% of data

# %%
trn.shape
# Out:
# (13684, 5)

# %%
tst.shape
# Out:
# (4561, 5)

# %%
ufo.shape
# Out:
# (18245, 5)

# %% [markdown]
# how to crate dummay variable for handeling string values (male and female --> 1 and 0)

# %%
train = pd.read_csv('data/titanic_train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train['Gender'] = train.Sex.map({'male':1,'female':0})
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
# OR
pd.get_dummies(train.Sex) # now we received two cols but we can delete one and still maintain all information
#pd.get_dummies(train.Sex).iloc[:,1:] # first column dropped
#gend = pd.get_dummies(train.Sex, prefix='gender').iloc[:,1:] # Add prefix
#pd.concat([train,gend], axis=1) # concate a col with DF
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
gend
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-f6fbc591e10f> in <module>
# ----> 1 gend
#
# NameError: name 'gend' is not defined

# %%
# to get multiple cols dummies
import pandas as pd
train = pd.read_csv('data/titanic_train.csv')
#train
#pd.get_dummies(train, columns = ['Embarked','Sex']).head() #now original cols are replaced with dummy cols

pd.get_dummies(train, columns = ['Embarked','Sex'],drop_first=True).head() # drop first col of each dummy
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked_Q  Embarked_S  Sex_male
# 0         A/5 21171   7.2500   NaN           0           1         1
# 1          PC 17599  71.2833   C85           0           0         0
# 2  STON/O2. 3101282   7.9250   NaN           0           1         0
# ...

# %%
# to find duplicate values of particluar col
ucol = ['id','age','gender','occupation','code']
user = pd.read_table('data/movieusers.tsv',sep='|', header=None,names=ucol)
user.code.duplicated().sum()
# Out:
# 148

# %%
user.duplicated().sum()
#.sum() # over all duplicates
# Out:
# 0

# %%
#user.loc[user.code.duplicated(),:] #to show duplicated values
#user.loc[user.code.duplicated(keep='first'),:]
#user.loc[user.code.duplicated(keep='last'),:]
user.loc[user.code.duplicated(keep=False),:]
# Out:
#       id  age gender     occupation   code
# 0      1   24      M     technician  85711
# 1      2   53      F          other  94043
# 6      7   57      M  administrator  91344
# 13    14   45      M      scientist  55106
# 14    15   49      F       educator  97301
# ..   ...  ...    ...            ...    ...
# 927  928   21      M        student  55408
# 928  929   44      M      scientist  53711
# 933  934   61      M       engineer  22902
# 936  937   48      M       educator  98072
# 939  940   32      M  administrator  02215
#
# [250 rows x 5 columns]

# %%
user.drop_duplicates(keep='first')
# Out:
#       id  age gender     occupation   code
# 0      1   24      M     technician  85711
# 1      2   53      F          other  94043
# 2      3   23      M         writer  32067
# 3      4   24      M     technician  43537
# 4      5   33      F          other  15213
# ..   ...  ...    ...            ...    ...
# 938  939   26      F        student  33319
# 939  940   32      M  administrator  02215
# 940  941   20      M        student  97229
# 941  942   48      F      librarian  78209
# 942  943   22      M        student  77841
#
# [943 rows x 5 columns]

# %%
user.duplicated(subset=['age','code']).sum() # to find duplicates of multiple cols
# Out:
# 16

# %%
user.drop_duplicates(subset=['age','code']).shape # to find duplicates of multiple cols
# Out:
# (927, 5)

# %%
import pandas as pd
movies = pd.read_csv('data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.content_rating.isnull().sum() #counting the missing values in the 'content_rating'
# Out:
# 3

# %%
movies[movies.content_rating.isnull()] # rows containing null in 'content_rating'
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies.content_rating.value_counts(dropna=False) # unique values of Content Rating
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# NaN            3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
movies[movies.content_rating=='NOT RATED'].head() # to show "NOT RATED" rows
# Out:
#     star_rating                           title content_rating    genre  \
# 5           8.9                    12 Angry Men      NOT RATED    Drama
# 6           8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 41          8.5                    Sunset Blvd.      NOT RATED    Drama
# 63          8.4                               M      NOT RATED    Crime
# 66          8.4             Munna Bhai M.B.B.S.      NOT RATED   Comedy
#
#     duration                                        actors_list
# 5         96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6        161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 41       110  [u'William Holden', u'Gloria Swanson', u'Erich...
# 63        99  [u'Peter Lorre', u'Ellen Widmann', u'Inge Land...
# 66       156   [u'Sunil Dutt', u'Sanjay Dutt', u'Arshad Warsi']

# %%
movies[movies.content_rating=='NOT RATED'].content_rating.head() # then, select the 'content_rating' Series from those rows
# Out:
# 5     NOT RATED
# 6     NOT RATED
# 41    NOT RATED
# 63    NOT RATED
# 66    NOT RATED
# Name: content_rating, dtype: object

# %%
# finally, replace the 'NOT RATED' values with 'NaN' (imported from NumPy)
import numpy as np
movies[movies.content_rating=='NOT RATED'].content_rating = np.nan
# Out:
# C:\Users\Adam\Anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# Problem: That statement involves two operations, a __getitem__ and a __setitem__. pandas can't guarantee whether the __getitem__ operation returns a view or a copy of the data.
# If __getitem__ returns a view of the data, __setitem__ will affect the 'movies' DataFrame.
# But if __getitem__ returns a copy of the data, __setitem__ will not affect the 'movies' DataFrame.

# %%
# the 'content_rating' Series has not changed
movies.content_rating.isnull().sum()
# Out:
# 3

# %%
# replace the 'NOT RATED' values with 'NaN' (does not cause a SettingWithCopyWarning)
movies.loc[movies.content_rating=='NOT RATED', 'content_rating'] = np.nan

# %%
# this time, the 'content_rating' Series has changed
movies.content_rating.isnull().sum()
# Out:
# 68

# %%
top_movies = movies.loc[movies.star_rating >= 9, :]
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
top_movies.loc[0, 'duration'] = 150
# Out:
# C:\Users\Adam\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
top_movies # 'top_movies' DataFrame has been updated
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       150
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
movies.head(1) # 'movies' DataFrame has not been updated
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
# explicitly create a copy of 'movies'
top_movies = movies.loc[movies.star_rating >= 9, :].copy()

# %%
# pandas now knows that you are updating a copy instead of a view (does not cause a SettingWithCopyWarning)
top_movies.loc[0, 'duration'] = 150

# %%
# 'top_movies' DataFrame has been updated
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       150
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %% [markdown]
# display options

# %%
movies # show only sixty values
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# check the current setting for the 'max_rows' option
pd.get_option('display.max_rows')
# Out:
# 60

# %%
# overwrite the current setting so that all rows will be displayed
pd.set_option('display.max_rows', None)

# %%
movies # now show all rows
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
# reset the 'max_rows' option to its default
pd.reset_option('display.max_rows')

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# the 'max_columns' option is similar to 'max_rows'
pd.get_option('display.max_columns')
# Out:
# 20
